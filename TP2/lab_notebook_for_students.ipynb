# %% [markdown]
# # CSC 8614 - Language Models
# ## CI2 - Fine-tuning a language model for text classification
#
# In this TP, you will work on fine-tuning a language model to move from text generation to text classification, specifically working on Spam Detection.
#
# The exercise (and code) has been adapted from the book _Build a Large Language Model (From Scratch)_, by Sebastian Raschka, and its [official github repository](https://github.com/rasbt/LLMs-from-scratch).
#
# This TP will be done in this notebook, and requires some additional files (available from the course website). You will have to fill the missing portions of code, and perform some additional experiments by testing different parameters.
#
# Working on this TP:
# - The easiest way is probably to work directly on the notebook, using jupyter notebook or visual studio code. An alternative is also to use Google colab.
# - You should be able to run everything on your machine, but you can connect to the GPUs if needed.
#
# Some files are required, and are available on the course website:
# - `requirements.txt`
# - `gpt_utils.py`
#
#
# ## About the report
# You will have to return this notebook (completed), as well as a mini-report (`TP2/rapport.md`).
#
# The notebook and report shall be submitted via a GitHub repository, similarly to what you did for the first session (remember to use a different folder: `TP2`).
# For the notebook, it is sufficient to complete the code and submit the final version.
#
# For the mini-report, you have to answer the questions asked in this notebook, and discuss some of your findings as requested.
# As for the first session:
# - "Vous devez y mettre : réponses courtes, résultats observés (copie de sorties), captures d’écran demandées, et une courte interprétation."
# - "Ne collez pas des pages entières : soyez concis et sélectionnez les éléments pertinents."
#
# Reproducibility:
# - fix a random seed and write it in the report
# - indicate in the report the specific python version OS, and the library versions.

# %% [markdown]
# **Question 1**: Dans `TP1/rapport.md`, ajoutez immédiatement un court en-tête (quelques lignes) contenant : (i) votre nom/prénom, (ii) la commande d’installation/activation d’environnement utilisée, (iii) les versions (Python + bibliothèques principales).
#
# Ajoutez ensuite au fil du TP des sections/titres à votre convenance, tant que l’on peut retrouver clairement vos réponses et vos preuves d’exécution.

# %%
# [Instructor code: install requirements]
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch==2.9.1 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (2.9.1)
# Requirement already satisfied: tiktoken==0.12.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (0.12.0)
# Requirement already satisfied: tqdm==4.67.1 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (4.67.1)
# Requirement already satisfied: pandas==2.3.3 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (2.3.3)
# Requirement already satisfied: matplotlib==3.10.8 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (3.10.8)
# Requirement already satisfied: tensorflow==2.20.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (2.20.0)
# Requirement already satisfied: jupyterlab==4.5.1 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (4.5.1)
# Requirement already satisfied: filelock in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (3.20.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: setuptools in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (3.6.1)
# Requirement already satisfied: jinja2 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (2025.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (3.5.1)
# Requirement already satisfied: regex>=2022.1.18 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from tiktoken==0.12.0->-r requirements.txt (line 2)) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from tiktoken==0.12.0->-r requirements.txt (line 2)) (2.32.5)
# Requirement already satisfied: numpy>=1.26.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from pandas==2.3.3->-r requirements.txt (line 4)) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from pandas==2.3.3->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from pandas==2.3.3->-r requirements.txt (line 4)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from pandas==2.3.3->-r requirements.txt (line 4)) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from matplotlib==3.10.8->-r requirements.txt (line 5)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from matplotlib==3.10.8->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from matplotlib==3.10.8->-r requirements.txt (line 5)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from matplotlib==3.10.8->-r requirements.txt (line 5)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from matplotlib==3.10.8->-r requirements.txt (line 5)) (25.0)
# Requirement already satisfied: pillow>=8 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from matplotlib==3.10.8->-r requirements.txt (line 5)) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from matplotlib==3.10.8->-r requirements.txt (line 5)) (3.3.1)
# Requirement already satisfied: absl-py>=1.0.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (3.4.0)
# Requirement already satisfied: protobuf>=5.28.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (6.33.4)
# Requirement already satisfied: six>=1.12.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (3.13.1)
# Requirement already satisfied: h5py>=3.11.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (0.5.4)
# Requirement already satisfied: async-lru>=1.0.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 7)) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 7)) (7.1.0)
# Requirement already satisfied: jupyter-core in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 7)) (5.9.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 7)) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 7)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 7)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 7)) (6.5.4)
# Requirement already satisfied: traitlets in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 7)) (5.14.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow==2.20.0->-r requirements.txt (line 6)) (0.45.1)
# Requirement already satisfied: anyio in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (4.12.1)
# Requirement already satisfied: certifi in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (1.0.9)
# Requirement already satisfied: idna in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.16.0)
# Requirement already satisfied: comm>=0.1.1 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (1.8.19)
# Requirement already satisfied: ipython>=7.23.1 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (9.9.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (8.8.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (7.2.1)
# Requirement already satisfied: pyzmq>=25 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (27.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jinja2->torch==2.9.1->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: platformdirs>=2.5 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyter-core->jupyterlab==4.5.1->-r requirements.txt (line 7)) (4.5.1)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.24.1)
# Requirement already satisfied: send2trash>=1.8.2 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.13.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (4.26.0)
# Requirement already satisfied: rich in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow==2.20.0->-r requirements.txt (line 6)) (14.2.0)
# Requirement already satisfied: namex in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow==2.20.0->-r requirements.txt (line 6)) (0.1.0)
# Requirement already satisfied: optree in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow==2.20.0->-r requirements.txt (line 6)) (0.18.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken==0.12.0->-r requirements.txt (line 2)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken==0.12.0->-r requirements.txt (line 2)) (2.6.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch==2.9.1->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow==2.20.0->-r requirements.txt (line 6)) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow==2.20.0->-r requirements.txt (line 6)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow==2.20.0->-r requirements.txt (line 6)) (3.1.5)
# Requirement already satisfied: argon2-cffi-bindings in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (25.1.0)
# Requirement already satisfied: decorator>=4.3.2 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.6.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (6.3.0)
# Requirement already satisfied: defusedxml in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (2.21.2)
# Requirement already satisfied: ptyprocess in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from rich->keras>=3.10.0->tensorflow==2.20.0->-r requirements.txt (line 6)) (4.0.0)
# Requirement already satisfied: webencodings in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (1.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.8.5)
# Requirement already satisfied: fqdn in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (1.5.1)
# Requirement already satisfied: isoduration in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (1.1.0)
# Requirement already satisfied: uri-template in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (25.10.0)
# Requirement already satisfied: mdurl~=0.1 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow==2.20.0->-r requirements.txt (line 6)) (0.1.2)
# Requirement already satisfied: wcwidth in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.2.14)
# Requirement already satisfied: executing>=1.2.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (3.0.1)
# Requirement already satisfied: pure-eval in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.2.3)
# Requirement already satisfied: cffi>=1.0.1 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (2.0.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (2.8.1)
# Requirement already satisfied: pycparser in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (2.23)
# Requirement already satisfied: lark>=1.2.2 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /home/zriga/workspace/Modeles_de_langage/.venv/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (1.4.0)

# %% [markdown]
# ## Preparing the model

# %%
# --- [INSTRUCTOR CODE: load the model weights into memory] ---
import torch
import tiktoken
from gpt_utils import GPTModel, download_and_load_gpt2, load_weights_into_gpt

# Download the model weights (124M param version) / This function (which we put in gpt_utils) handles the downloading
settings, params = download_and_load_gpt2(model_size="124M", models_dir="gpt2_weights")
print("Weights downloaded and loaded into memory.")
# Out:
# 2026-01-16 17:37:16.297098: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# checkpoint: 100%|██████████| 77.0/77.0 [00:00<00:00, 67.1kiB/s]
# encoder.json: 100%|██████████| 1.04M/1.04M [00:02<00:00, 362kiB/s]
# hparams.json: 100%|██████████| 90.0/90.0 [00:00<00:00, 25.2kiB/s]
# model.ckpt.data-00000-of-00001: 100%|██████████| 498M/498M [00:56<00:00, 8.75MiB/s]
# model.ckpt.index: 100%|██████████| 5.21k/5.21k [00:00<00:00, 2.53MiB/s]
# model.ckpt.meta: 100%|██████████| 471k/471k [00:01<00:00, 288kiB/s]
# vocab.bpe: 100%|██████████| 456k/456k [00:01<00:00, 263kiB/s]
# Weights downloaded and loaded into memory.
# 2026-01-16 17:38:30.410070: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 154389504 exceeds 10% of free system memory.

# %% [markdown]
# The `settings` obtained with `download_and_load_gpt2` are the GPT-2 weights made publicly available by OpenAI.
#
# **Question 2**: What type is the object `setting`, and what is its structure (e.g. if it is a list, its length; if a dictionary, its keys, etc.)?
#
# **Question 3**: What type is the object `params`, and what is its structure?

# %%
# Analyse `settings`
# TODO: your code here.
print("type(settings):", type(settings))

if isinstance(settings, dict):
    print("len(settings):", len(settings))
    print("keys:", list(settings.keys()))
    # Afficher types/valeurs
    for k in settings:
        print(k, "->", settings[k], "(type:", type(settings[k]), ")")

# Analyse `params`
# TODO: your code here.
print("type(params):", type(params))

if isinstance(params, dict):
    print("Nombre de clés (top-level):", len(params))
    print("Exemples de clés:", list(params.keys())[:20])

    # Inspecter quelques sous-structures
    for k in list(params.keys())[:5]:
        v = params[k]
        if isinstance(v, dict):
            print(f"{k}: dict, len={len(v)}, subkeys={list(v.keys())[:10]}")
        else:
            try:
                print(f"{k}: type={type(v)}, shape={getattr(v, 'shape', None)}")
            except Exception:
                print(f"{k}: type={type(v)}")
else:
    print("params:", params)
# Out:
# type(settings): <class 'dict'>
# len(settings): 5
# keys: ['n_vocab', 'n_ctx', 'n_embd', 'n_head', 'n_layer']
# n_vocab -> 50257 (type: <class 'int'> )
# n_ctx -> 1024 (type: <class 'int'> )
# n_embd -> 768 (type: <class 'int'> )
# n_head -> 12 (type: <class 'int'> )
# n_layer -> 12 (type: <class 'int'> )
# type(params): <class 'dict'>
# Nombre de clés (top-level): 5
# Exemples de clés: ['blocks', 'b', 'g', 'wpe', 'wte']
# blocks: type=<class 'list'>, shape=None
# b: type=<class 'numpy.ndarray'>, shape=(768,)
# g: type=<class 'numpy.ndarray'>, shape=(768,)
# wpe: type=<class 'numpy.ndarray'>, shape=(1024, 768)
# wte: type=<class 'numpy.ndarray'>, shape=(50257, 768)

# %% [markdown]
# Look at the `GPTModel` in the file `gpt_utils.py`. In the `__init__` method, we have to pass a config (parameter `cfg`).
#
# **Question 4:**
# Analyse the `__init__` method, and check what is the required structure for the `cfg` parameter. Is the `settings` variable we have obtained in the right format? If not, perform the mapping to convert the variable `setting` into a variable `model_config` with the right structure.

# %%
# Configure the model, mapping OpenAI specific keys to our model's keys (if needed)
model_config = {
    # TODO: add your code here, but keep the two lines below.
    "vocab_size": settings["n_vocab"],
    "context_length": settings["n_ctx"],
    "emb_dim": settings["n_embd"],
    "n_heads": settings["n_head"],
    "n_layers": settings["n_layer"],
    "drop_rate": 0.1,
    "qkv_bias": True,
}

# %%
model = GPTModel(model_config)

# Load the pre-trained weights
load_weights_into_gpt(model, params)
model.eval() 

print("GPT-2 Model Loaded and Configured successfully!")
# Out:
# GPT-2 Model Loaded and Configured successfully!

# %% [markdown]
# ## Preparing the data
#
# Context from the lecture: The raw data is just text messages.
#
# The model needs numbers (token IDs). We also need to pad the messages so they are all the same length in a batch.
#
# We will use a `SpamDataset` class (provided below) to tokenize the text.

# %%
# --- [INSTRUCTOR CODE: Run this cell to define the Dataset Class] ---
from torch.utils.data import Dataset
import pandas as pd
import urllib.request
import zipfile
import os

class SpamDataset(Dataset):
    def __init__(self, csv_file, tokenizer, max_length=120, pad_token_id=50256):
        self.data = pd.read_csv(csv_file)
        self.tokenizer = tokenizer
        self.max_length = max_length
        self.pad_token_id = pad_token_id
        # Encode labels: "spam" -> 1, "ham" -> 0
        self.data["label_encoded"] = self.data["Label"].map({"spam": 1, "ham": 0})

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        text = self.data.iloc[idx]["Text"]
        label = self.data.iloc[idx]["label_encoded"]
        # Tokenize
        encoded = self.tokenizer.encode(text, allowed_special={'<|endoftext|>'})       
        # Truncate if too long
        encoded = encoded[:self.max_length]
        # Pad if too short
        pad_len = self.max_length - len(encoded)
        encoded += [self.pad_token_id] * pad_len
        return torch.tensor(encoded, dtype=torch.long), torch.tensor(label, dtype=torch.long)

# Download the dataset zip file
url = "https://archive.ics.uci.edu/static/public/228/sms+spam+collection.zip"
zip_path = "sms_spam_collection.zip"
extract_path = "sms_spam_collection"
data_file_path = os.path.join(extract_path, "SMSSpamCollection")
if not os.path.exists(zip_path):
    print("Downloading dataset...")
    urllib.request.urlretrieve(url, zip_path)
    print("Download complete.")
# Unzip
if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, "r") as zip_ref:
        zip_ref.extractall(extract_path)
# Read the TSV file
df = pd.read_csv(
    data_file_path, 
    sep="\t", 
    header=None, 
    names=["Label", "Text"]
)
print(f"Total samples loaded: {len(df)}")

# 4. Create Train/Test Split (80 train / 20 test)
df = df.sample(frac=1, random_state=123).reset_index(drop=True)
# Split index
split_idx = int(0.8 * len(df))

# TODO: if needed (for performance resons), you can come back here and reduce the size of the training set.
train_df = df.iloc[:split_idx]  # [:2000]  # Readd this to only consider 2000 training samples
test_df = df.iloc[split_idx:]

# Save as CSVs, so the SpamDataset class can read them.
train_df.to_csv("train.csv", index=False)
test_df.to_csv("test.csv", index=False)
print("Created 'train.csv' and 'test.csv' successfully!")
print(f"Train size: {len(train_df)}")
print(f"Test size: {len(test_df)}")
# Out:
# Downloading dataset...
# Download complete.
# Total samples loaded: 5572
# Created 'train.csv' and 'test.csv' successfully!
# Train size: 4457
# Test size: 1115

# %% [markdown]
# **Question 5.1**: In the cell above, why did we do `df = df.sample(frac=1, random_state=123)` when creating the train/test split?
#
# **Question 5.2**: Analyse the datasets, what is the distribution of the two classes in the train set? Are they balanced or unbalanced? In case they are unbalanced, might this lead to issues for the fine-tuning of the model?

# %%
# TODO: Your code here.
train_counts = train_df["Label"].value_counts()
train_props = train_df["Label"].value_counts(normalize=True)

print("Train counts:\n", train_counts)
print("\nTrain proportions:\n", train_props)

# Vérification du test
test_counts = test_df["Label"].value_counts()
test_props = test_df["Label"].value_counts(normalize=True)

print("\nTest counts:\n", test_counts)
print("\nTest proportions:\n", test_props)
# Out:
# Train counts:
#  Label
# ham     3860
# spam     597
# Name: count, dtype: int64
#
# Train proportions:
#  Label
# ham     0.866053
# spam    0.133947
# Name: proportion, dtype: float64
#
# Test counts:
#  Label
# ham     965
# spam    150
# Name: count, dtype: int64
#
# Test proportions:
#  Label
# ham     0.865471
# spam    0.134529
# Name: proportion, dtype: float64

# %% [markdown]
# **Question 6**: Create the dataloaders for training and test.

# %%
# TODO: add any imports which are needed
from torch.utils.data import DataLoader

# Create the Tokenizer
tokenizer = tiktoken.get_encoding("gpt2")

# Instantiate the Dataset
train_dataset = SpamDataset("train.csv", tokenizer)
test_dataset = SpamDataset("test.csv", tokenizer)

# --- TODO: Create DataLoaders ---
# 1. Create a train_loader with batch_size=16 and shuffle=True
train_loader = DataLoader(
    train_dataset,
    batch_size=16,
    shuffle=True
)
# 2. Create a test_loader with batch_size=16 and shuffle=False
test_loader = DataLoader(
    test_dataset,
    batch_size=16,
    shuffle=False
)

# %%
# Check your work
for input_batch, target_batch in train_loader:
    print("Input batch shape:", input_batch.shape) # Should be [16, 120] (unless you use batch_size != 16)
    print("Target batch shape:", target_batch.shape) # Should be [16]
    break
# Out:
# Input batch shape: torch.Size([16, 120])
# Target batch shape: torch.Size([16])

# %% [markdown]
# **Question 7**: Looking at the batch size and the training size, how many batches will you have in total? Please report the size of the subsampled training data, you reduce it due to performance constraints.

# %%
# TODO: add your code.
import math

train_size = len(train_dataset)
batch_size = 16
num_batches = math.ceil(train_size / batch_size)

print("Train size:", train_size)
print("Batch size:", batch_size)
print("Number of batches per epoch:", num_batches)
# Out:
# Train size: 4457
# Batch size: 16
# Number of batches per epoch: 279

# %% [markdown]
# ## Fine-tuning

# %% [markdown]
# **Context**: GPT-2 was trained to predict the next word (output size ~50,000). We want to predict binary classes (output size 2), so we must replace the final layer.

# %% [markdown]
# **Question 8**:
#
# **8.1**: In the cell below, define the number of output classes (`num_classes`) for the new spam detection task.
#
# **8.2**: Also, pring the original and updated output heads (hint: `out_head` from `GPTModel`)
#
# **8.3**: Why do we freeze the internal layers with `param.requires_grad = False`?

# %%
import torch.nn as nn

# Freeze the internal layers
for param in model.parameters():
    param.requires_grad = False

print("Original output head:", model.out_head)

num_classes = 2
model.out_head = nn.Linear(768, num_classes, bias=True)
# Hint: The input size of the last layer in GPT-2 small is 768.

# Enable gradient calculation ONLY for the new head and the final LayerNorm
for param in model.out_head.parameters():
    param.requires_grad = True
for param in model.trf_blocks[-1].norm2.parameters():
    param.requires_grad = True

print("New output head:", model.out_head)
# Out:
# Original output head: Linear(in_features=768, out_features=50257, bias=False)
# New output head: Linear(in_features=768, out_features=2, bias=True)

# %% [markdown]
# You now have to **finalise the code for the training loop** (see individual steps below).
#
# In the first cell below you can find the code to move the model to GPU (if available), define the optimizer, and calculate the accuracy. The following cell contains the code for the training (fine-tuning) loop.
#
# You will have to complete the code of the training loop, by answering the following questions:
#
# **Question 9.1**: Reset the gradients of the `optimizer` ([hint](https://docs.pytorch.org/docs/stable/generated/torch.optim.Optimizer.zero_grad.html)).
#
# **Question 9.2**: Compute cross-entropy loss ([hint](https://docs.pytorch.org/docs/stable/generated/torch.nn.functional.cross_entropy.html)).
#
# **Question 9.3**: Add code for the backward pass, to compute the gradient ([hint](https://docs.pytorch.org/docs/stable/generated/torch.nn.functional.cross_entropy.html))
#
# **Question 9.4**: Add code for the optimizer step, to update the weights ([hint](https://docs.pytorch.org/docs/stable/generated/torch.optim.Optimizer.step.html))
#
# **Question 9.5**: Add code to calculate the accuracy on train and test (hint: you can use the `calc_accuracy` method).
#
# **Note about the speed**: On my laptop's CPU 1 epoch with the full training dataset (~4400 samples, batch_size=16) took ~20 minutes; 1 epoch with a train set of 2000 samples (batch_size=16) took ~12 minutes.
#
# To iterate more quickly, you could:
# - i) set `num_epochs = 1` (but only at the beginning), just to make sure that the code is working;
# - ii) increase batch_size to 32 or 64 (but careful with possible memory issues).
# - iii) reduce the size of the training dataset, by going back to the *Preparing the data* section, and changing the line `train_df = df.iloc[:split_idx]` to `train_df = df.iloc[:split_idx][:2000]` or similar. Be careful that if you reduce the training data too much, the model will not have enough data for fine-tuning.
# - Use a GPU; it would be much quicker (few minutes on the whole training data).

# %%
# [--- INSTRUCTOR CODE ---]

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Measure imbalance
count_ham = len(train_df[train_df['Label']=='ham'])
count_spam = len(train_df[train_df['Label']=='spam'])

# Calculate weight: penalize missing the minority class (Spam) more
# Weight = Count(Majority) / Count(Minority)
pos_weight = count_ham / count_spam  # approx 6.46 (for full training dataset)
class_weights = torch.tensor([1.0, pos_weight]).to(device)
print(f"Using class weights: {class_weights}")

# Define Optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=5e-5, weight_decay=0.1)

# Calculate Accuracy Helper Function
def calc_accuracy(loader, model, device):
    correct, total = 0, 0
    # Track spam specifically
    spam_correct, spam_total = 0, 0
    model.eval()
    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            logits = model(inputs)[:, -1, :]
            predicted = torch.argmax(logits, dim=-1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            # Filter for Spam (Label 1)
            spam_mask = (labels == 1)
            spam_total += spam_mask.sum().item()
            spam_correct += (predicted[spam_mask] == labels[spam_mask]).sum().item()
    # Avoid division by zero
    spam_acc = spam_correct / spam_total if spam_total > 0 else 0.0
    global_acc = correct / total
    return global_acc, spam_acc
# Out:
# Using class weights: tensor([1.0000, 6.4657])

# %%
# TODO: Add your code where needed in this cell
import torch.nn as nn

loss_fn = nn.CrossEntropyLoss(weight=class_weights)

num_epochs = 1  # TODO: (Optional questions: update this to see how the fine-tuning changes with more epochs)

for epoch in range(num_epochs):
    model.train()
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)

        # 9.1. Reset Gradients (of the `optimizer`)
        # TODO: YOUR CODE HERE
        optimizer.zero_grad()
        
        # Forward Pass. The model outputs (batch, seq_len, vocab_size). 
        # We only want the prediction for the LAST token in the sequence.
        logits = model(inputs)[:, -1, :]

        # 9.2. Calculate the cross entropy loss
        loss = loss_fn(logits, targets) # TODO: YOUR CODE HERE

        # 9.3. Backward Pass
        # TODO: YOUR CODE HERE
        loss.backward()

        # 9.4 Optimizer Step
        # TODO: YOUR CODE HERE
        optimizer.step()

        if batch_idx % 10 == 0:
            print(f"Epoch {epoch+1}, Batch {batch_idx}, Loss: {loss.item():.4f}")

    # 9.5 Add code to calculate the accuracy on train and test
    train_acc, train_spam_acc = calc_accuracy(train_loader, model, device) # TODO: YOUR CODE HERE
    test_acc, test_spam_acc = calc_accuracy(test_loader, model, device) # TODO: YOUR CODE HERE
    
    print(f"Epoch {epoch+1}: Train Acc: {train_acc*100:.2f}% (Spam: {train_spam_acc*100:.2f}%) | Test Acc: {test_acc*100:.2f}% (Spam: {test_spam_acc*100:.2f}%)")
# Out:
# Epoch 1, Batch 0, Loss: 2.5410
# Epoch 1, Batch 10, Loss: 4.2705
# Epoch 1, Batch 20, Loss: 1.8484
# Epoch 1, Batch 30, Loss: 0.8793
# Epoch 1, Batch 40, Loss: 1.4031
# Epoch 1, Batch 50, Loss: 1.1510
# Epoch 1, Batch 60, Loss: 0.6642
# Epoch 1, Batch 70, Loss: 0.8017
# Epoch 1, Batch 80, Loss: 0.9098
# Epoch 1, Batch 90, Loss: 0.6709
# Epoch 1, Batch 100, Loss: 0.7613
# Epoch 1, Batch 110, Loss: 0.7650
# Epoch 1, Batch 120, Loss: 0.7421
# Epoch 1, Batch 130, Loss: 0.7096
# Epoch 1, Batch 140, Loss: 0.6663
# Epoch 1, Batch 150, Loss: 0.7877
# Epoch 1, Batch 160, Loss: 0.7056
# Epoch 1, Batch 170, Loss: 0.5355
# Epoch 1, Batch 180, Loss: 0.7909
# Epoch 1, Batch 190, Loss: 0.7707
# Epoch 1, Batch 200, Loss: 0.7079
# Epoch 1, Batch 210, Loss: 0.5929
# Epoch 1, Batch 220, Loss: 0.8248
# Epoch 1, Batch 230, Loss: 0.6250
# Epoch 1, Batch 240, Loss: 0.7484
# Epoch 1, Batch 250, Loss: 0.7010
# Epoch 1, Batch 260, Loss: 0.6623
# Epoch 1, Batch 270, Loss: 0.5258
# Epoch 1: Train Acc: 86.58% (Spam: 0.00%) | Test Acc: 86.55% (Spam: 0.00%)

# %% [markdown]
# **Question 10**:
#
# Now run the cell above. You should see how the training loss changes after each batch (and epoch).
# Describe thie trend: what do you see, is the model learning?
#
# **Question 11 (optional)**: Change the number of epochs and/or the learning rate and/or the size of the training data, and investigate how the loss/accuracy of the model changes. You can do this editing and re-running the cells above, or creating new cells below.

# %%
# TODO if needed, your code for the additional analysis can go here.
# TODO: Add your code where needed in this cell
import torch.nn as nn

loss_fn = nn.CrossEntropyLoss(weight=class_weights)

num_epochs = 3  # TODO: (Optional questions: update this to see how the fine-tuning changes with more epochs)

for epoch in range(num_epochs):
    model.train()
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)

        # 9.1. Reset Gradients (of the `optimizer`)
        # TODO: YOUR CODE HERE
        optimizer.zero_grad()
        
        # Forward Pass. The model outputs (batch, seq_len, vocab_size). 
        # We only want the prediction for the LAST token in the sequence.
        logits = model(inputs)[:, -1, :]

        # 9.2. Calculate the cross entropy loss
        loss = loss_fn(logits, targets) # TODO: YOUR CODE HERE

        # 9.3. Backward Pass
        # TODO: YOUR CODE HERE
        loss.backward()

        # 9.4 Optimizer Step
        # TODO: YOUR CODE HERE
        optimizer.step()

        if batch_idx % 10 == 0:
            print(f"Epoch {epoch+1}, Batch {batch_idx}, Loss: {loss.item():.4f}")

    # 9.5 Add code to calculate the accuracy on train and test
    train_acc, train_spam_acc = calc_accuracy(train_loader, model, device) # TODO: YOUR CODE HERE
    test_acc, test_spam_acc = calc_accuracy(test_loader, model, device) # TODO: YOUR CODE HERE
    
    print(f"Epoch {epoch+1}: Train Acc: {train_acc*100:.2f}% (Spam: {train_spam_acc*100:.2f}%) | Test Acc: {test_acc*100:.2f}% (Spam: {test_spam_acc*100:.2f}%)")
# Out:
# Epoch 1, Batch 0, Loss: 0.7608
# Epoch 1, Batch 10, Loss: 0.6242
# Epoch 1, Batch 20, Loss: 0.7308
# Epoch 1, Batch 30, Loss: 0.5621
# Epoch 1, Batch 40, Loss: 0.7818
# Epoch 1, Batch 50, Loss: 0.6223
# Epoch 1, Batch 60, Loss: 0.7268
# Epoch 1, Batch 70, Loss: 0.7811
# Epoch 1, Batch 80, Loss: 0.7330
# Epoch 1, Batch 90, Loss: 0.6637
# Epoch 1, Batch 100, Loss: 0.8281
# Epoch 1, Batch 110, Loss: 0.5614
# Epoch 1, Batch 120, Loss: 0.5986
# Epoch 1, Batch 130, Loss: 0.9227
# Epoch 1, Batch 140, Loss: 0.6890
# Epoch 1, Batch 150, Loss: 0.7734
# Epoch 1, Batch 160, Loss: 0.6774
# Epoch 1, Batch 170, Loss: 0.7141
# Epoch 1, Batch 180, Loss: 0.6802
# Epoch 1, Batch 190, Loss: 0.6445
# Epoch 1, Batch 200, Loss: 0.7138
# Epoch 1, Batch 210, Loss: 0.7201
# Epoch 1, Batch 220, Loss: 0.6232
# Epoch 1, Batch 230, Loss: 0.7054
# Epoch 1, Batch 240, Loss: 0.6043
# Epoch 1, Batch 250, Loss: 0.5789
# Epoch 1, Batch 260, Loss: 0.7819
# Epoch 1, Batch 270, Loss: 0.7397
# Epoch 1: Train Acc: 86.58% (Spam: 0.00%) | Test Acc: 86.55% (Spam: 0.00%)
# Epoch 2, Batch 0, Loss: 0.6853
# Epoch 2, Batch 10, Loss: 0.6037
# Epoch 2, Batch 20, Loss: 0.8148
# Epoch 2, Batch 30, Loss: 0.5994
# Epoch 2, Batch 40, Loss: 0.9083
# Epoch 2, Batch 50, Loss: 0.7546
# Epoch 2, Batch 60, Loss: 0.6253
# Epoch 2, Batch 70, Loss: 0.6771
# Epoch 2, Batch 80, Loss: 0.8702
# Epoch 2, Batch 90, Loss: 0.7020
# Epoch 2, Batch 100, Loss: 0.7271
# Epoch 2, Batch 110, Loss: 0.6745
# Epoch 2, Batch 120, Loss: 0.7546
# Epoch 2, Batch 130, Loss: 0.6806
# Epoch 2, Batch 140, Loss: 0.5235
# Epoch 2, Batch 150, Loss: 0.7842
# Epoch 2, Batch 160, Loss: 0.8621
# Epoch 2, Batch 170, Loss: 0.6333
# Epoch 2, Batch 180, Loss: 0.7632
# Epoch 2, Batch 190, Loss: 0.7030
# Epoch 2, Batch 200, Loss: 0.5567
# Epoch 2, Batch 210, Loss: 0.7788
# Epoch 2, Batch 220, Loss: 0.6648
# Epoch 2, Batch 230, Loss: 0.7941
# Epoch 2, Batch 240, Loss: 0.6632
# Epoch 2, Batch 250, Loss: 0.6497
# Epoch 2, Batch 260, Loss: 0.6443
# Epoch 2, Batch 270, Loss: 0.6475
# Epoch 2: Train Acc: 86.49% (Spam: 0.00%) | Test Acc: 86.28% (Spam: 0.00%)
# Epoch 3, Batch 0, Loss: 0.8874
# Epoch 3, Batch 10, Loss: 0.8580
# Epoch 3, Batch 20, Loss: 0.5648
# Epoch 3, Batch 30, Loss: 0.6348
# Epoch 3, Batch 40, Loss: 0.6230
# Epoch 3, Batch 50, Loss: 0.7334
# Epoch 3, Batch 60, Loss: 0.5950
# Epoch 3, Batch 70, Loss: 0.5398
# Epoch 3, Batch 80, Loss: 0.9010
# Epoch 3, Batch 90, Loss: 0.6164
# Epoch 3, Batch 100, Loss: 0.8028
# Epoch 3, Batch 110, Loss: 0.6019
# Epoch 3, Batch 120, Loss: 0.6325
# Epoch 3, Batch 130, Loss: 0.6738
# Epoch 3, Batch 140, Loss: 0.5940
# Epoch 3, Batch 150, Loss: 0.6467
# Epoch 3, Batch 160, Loss: 0.8077
# Epoch 3, Batch 170, Loss: 0.5670
# Epoch 3, Batch 180, Loss: 0.6463
# Epoch 3, Batch 190, Loss: 0.5805
# Epoch 3, Batch 200, Loss: 0.5866
# Epoch 3, Batch 210, Loss: 0.6188
# Epoch 3, Batch 220, Loss: 0.5775
# Epoch 3, Batch 230, Loss: 0.6749
# Epoch 3, Batch 240, Loss: 0.5261
# Epoch 3, Batch 250, Loss: 0.6889
# Epoch 3, Batch 260, Loss: 0.7145
# Epoch 3, Batch 270, Loss: 0.7285
# Epoch 3: Train Acc: 89.28% (Spam: 65.83%) | Test Acc: 91.48% (Spam: 66.67%)

# %% [markdown]
# **Question 12 (optional)**: Now test the model *on your own text*.

# %%
def classify_text(text, model, tokenizer, device, max_length=120, pad_token_id=50256):
    model.eval()
    
    # Encode the text
    encoded = tokenizer.encode(text, allowed_special={'<|endoftext|>'})
    
    # Pad/Truncate 
    # (Matches the logic in SpamDataset so the model sees familiar input structures)
    encoded = encoded[:max_length]
    pad_len = max_length - len(encoded)
    encoded += [pad_token_id] * pad_len

    # Create tensor and add batch dimension
    encoded_tensor = torch.tensor(encoded).unsqueeze(0).to(device) # Shape: [1, max_length]

    # Get prediction
    with torch.no_grad():
        logits = model(encoded_tensor)[:, -1, :] # Logits for the last token
        predicted_label = torch.argmax(logits, dim=-1).item()

    return "SPAM" if predicted_label == 1 else "NOT SPAM"

# --- TODO: Test the model ---
# Create 2 strings: one clearly spam, one normal.
text_1 = "You have won $1000 Walmart gift card. Click the link to verify your account."  # YOUR TEXT HERE
text_2 = "Don't forget to submit the assignment before midnight."  # YOUR TEXT HERE

print(f"Text 1: {text_1} -> {classify_text(text_1, model, tokenizer, device)}")
print(f"Text 2: {text_2} -> {classify_text(text_2, model, tokenizer, device)}")
# Out:
# Text 1: You have won $1000 Walmart gift card. Click the link to verify your account. -> NOT SPAM
# Text 2: Don't forget to submit the assignment before midnight. -> NOT SPAM

# %% [markdown]
# ---
